# %% [markdown]
# # E-commerce Purchases

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ecom = pd.read_csv('Ecommerce Customers.csv')

# %%
ecom
# Out:
#                                Email  \
# 0          mstephenson@fernandez.com
# 1                  hduke@hotmail.com
# 2                   pallen@yahoo.com
# 3            riverarebecca@gmail.com
# 4      mstephens@davidson-herman.com
# 5             alvareznancy@lucas.biz
# 6              katherine20@yahoo.com
# 7                 awatkins@yahoo.com
# 8        vchurch@walter-martinez.com
# 9                   bonnie69@lin.biz
# 10             andrew06@peterson.com
# 11            ryanwerner@freeman.biz
# 12                 knelson@gmail.com
# 13             wrightpeter@yahoo.com
# 14             taylormason@gmail.com
# 15               jstark@anderson.com
# 16               wjennings@gmail.com
# 17          rebecca45@hale-bauer.biz
# 18           alejandro75@hotmail.com
# 19            samuel46@love-west.net
# 20                 megan33@gmail.com
# 21                 agolden@yahoo.com
# 22             vstafford@hotmail.com
# 23   denise22@hernandez-townsend.com
# ...

# %%
ecom.head(20)
# Out:
#                             Email  \
# 0       mstephenson@fernandez.com
# 1               hduke@hotmail.com
# 2                pallen@yahoo.com
# 3         riverarebecca@gmail.com
# 4   mstephens@davidson-herman.com
# 5          alvareznancy@lucas.biz
# 6           katherine20@yahoo.com
# 7              awatkins@yahoo.com
# 8     vchurch@walter-martinez.com
# 9                bonnie69@lin.biz
# 10          andrew06@peterson.com
# 11         ryanwerner@freeman.biz
# 12              knelson@gmail.com
# 13          wrightpeter@yahoo.com
# 14          taylormason@gmail.com
# 15            jstark@anderson.com
# 16            wjennings@gmail.com
# 17       rebecca45@hale-bauer.biz
# 18        alejandro75@hotmail.com
# 19         samuel46@love-west.net
#
#                                               Address            Avatar  \
# 0        835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1      4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# ...

# %%
ecom.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
ecom.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
len(ecom.columns)
# Out:
# 8

# %%
len(ecom.index)
# Out:
# 500

# %%
# info() method gives more details

ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Email                   500 non-null object
# Address                 500 non-null object
# Avatar                  500 non-null object
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 31.3+ KB

# %%
# Average Yearly Amount spent?
ecom['Yearly Amount Spent'].mean()
# Out:
# 499.3140382585909

# %%
#What are the highest and lowest yearly amount spent
# Highest
ecom['Yearly Amount Spent'].max()
# Out:
# 765.5184619388373

# %%
# Lowest
ecom['Yearly Amount Spent'].min()
# Out:
# 256.67058229005585

# %%
# How many people have violet as avatar
ecom['Avatar']== 'violet'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 470    False
# 471    False
# 472    False
# 473    False
# 474    False
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# 480    False
# 481    False
# 482    False
# 483    False
# 484    False
# 485    False
# 486    False
# 487    False
# 488    False
# 489    False
# 490    False
# 491    False
# 492    False
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Avatar, Length: 500, dtype: bool

# %%
# Then do:
ecom[ecom['Avatar']== 'Tomato']
# Out:
#                       Email  \
# 10    andrew06@peterson.com
# 11   ryanwerner@freeman.biz
# 115       whess@hotmail.com
# 210    melissa08@nelson.com
# 214      drew29@hotmail.com
# 327   john85@rodriguez.info
#
#                                                Address  Avatar  \
# 10   26104 Alexander Groves\nAlexandriaport, WY 282...  Tomato
# 11               Unit 2413 Box 0347\nDPO AA 07580-2652  Tomato
# 115  29282 Alexander Street\nSouth Andrewmouth, MS ...  Tomato
# 210  15863 Harrington Glens Suite 012\nMarystad, LA...  Tomato
# 214         20888 Erin Via\nGrahamville, NH 72913-6101  Tomato
# 327      57120 Frank Keys\nJerryborough, DC 81028-0939  Tomato
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 10             33.992573    13.338975        37.225806              2.482608
# 11             33.879361    11.584783        37.087926              3.713209
# 115            33.235607    11.223369        37.692301              2.594190
# ...

# %%
# To know how many people:
ecom[ecom['Avatar']== 'Tomato'].count()
# Out:
# Email                   6
# Address                 6
# Avatar                  6
# Avg. Session Length     6
# Time on App             6
# Time on Website         6
# Length of Membership    6
# Yearly Amount Spent     6
# dtype: int64

# %%
# If you want just for the language column
ecom[ecom['Avatar']== 'Tomato']['Avatar'].count()
# Out:
# 6

# %%
# How many people had time on app  > 38
ecom[ecom['Time on Website'] > 38].count()
# Out:
# Email                   84
# Address                 84
# Avatar                  84
# Avg. Session Length     84
# Time on App             84
# Time on Website         84
# Length of Membership    84
# Yearly Amount Spent     84
# dtype: int64

# %%
# To see the index
ecom[ecom['Time on Website'] > 38].index
# Out:
# Int64Index([  0,  17,  18,  22,  33,  35,  45,  54,  56,  60,  69,  72,  74,
#              75,  78,  80,  95,  96,  98, 104, 108, 109, 112, 118, 131, 143,
#             144, 150, 158, 159, 160, 162, 166, 174, 176, 181, 189, 203, 206,
#             210, 212, 216, 222, 239, 242, 255, 258, 263, 270, 281, 284, 287,
#             289, 297, 301, 320, 326, 328, 335, 336, 338, 351, 361, 365, 371,
#             374, 379, 386, 394, 398, 403, 407, 410, 415, 427, 429, 430, 437,
#             464, 472, 476, 479, 488, 497],
#            dtype='int64')

# %%
ecom[ecom['Time on Website'] > 38].count()
# Out:
# Email                   84
# Address                 84
# Avatar                  84
# Avg. Session Length     84
# Time on App             84
# Time on Website         84
# Length of Membership    84
# Yearly Amount Spent     84
# dtype: int64

# %%
# or
len(ecom[ecom['Time on Website'] > 38].index)
# Out:
# 84

# %%
ecom.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
# How many members length of memebership > 4 and less than or equal to 4
#print(len(ecom[ecom['Length of Membership']<4].count()))
len(ecom[ecom['Length of Membership']<5].count())
# Out:
# 8

# %%
# What are the 5 most common Avatars:
ecom['Avatar'].value_counts().head(5)
# Out:
# GreenYellow    7
# CadetBlue      7
# SlateBlue      7
# Teal           7
# Cyan           7
# Name: Avatar, dtype: int64

# %%
# Locate SaddleBrown Times on APP
ecom[ecom['Avatar']=='SaddleBrown']
# Out:
#                          Email  \
# 3      riverarebecca@gmail.com
# 350          qeaton@savage.com
# 355  beasleyjoseph@hotmail.com
# 374          aaron89@gmail.com
# 415          brian51@cook.info
# 462        scottrose@yahoo.com
#
#                                                Address       Avatar  \
# 3     1414 David Throughway\nPort Jason, OH 22070-1220  SaddleBrown
# 350        27032 Michelle Forest\nMorrowtown, ND 14749  SaddleBrown
# 355   1094 Bentley Forges\nLake Antonio, MA 29181-3664  SaddleBrown
# 374  0128 Sampson Loop Suite 943\nHoffmanton, MO 02122  SaddleBrown
# 415    0508 Terrance Cliff\nRebekahtown, NC 48724-8308  SaddleBrown
# 462     50639 Sarah Isle Apt. 268\nYangmouth, MO 05540  SaddleBrown
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 3              34.305557    13.717514        36.721283              3.120179
# 350            33.304337    12.692661        37.333591              3.827376
# ...

# %%
# What is the email of the person that spent Yearly amount = 418.602742

# %%
ecom[ecom['Yearly Amount Spent']== 418.602742]['Email']
# Out:
# Series([], Name: Email, dtype: object)

# %%
# How many people spent over 12 on internet and spent over 450
ecom[(ecom['Time on App']>12) & (ecom['Yearly Amount Spent']>450)]
# Out:
#                                  Email  \
# 0            mstephenson@fernandez.com
# 3              riverarebecca@gmail.com
# 4        mstephens@davidson-herman.com
# 5               alvareznancy@lucas.biz
# 7                   awatkins@yahoo.com
# 8          vchurch@walter-martinez.com
# 10               andrew06@peterson.com
# 13               wrightpeter@yahoo.com
# 14               taylormason@gmail.com
# 15                 jstark@anderson.com
# 18             alejandro75@hotmail.com
# 19              samuel46@love-west.net
# 24              youngbarbara@yahoo.com
# 26            ijones@schaefer-carr.net
# 27               heatherhall@yahoo.com
# 30           jenniferbarnett@gmail.com
# 32       briancarlson@page-fleming.com
# 33                joshuaodom@gmail.com
# 39         teresaallen@hill-leach.info
# 42         jasonrichardson@elliott.com
# 45               brianwilson@yahoo.com
# 46             gonzaleskatie@gmail.com
# 47                    lsmith@chung.com
# ...

# %%
# How many:
ecom[(ecom['Time on App']>12) & (ecom['Yearly Amount Spent']>450)].count()
# Out:
# Email                   217
# Address                 217
# Avatar                  217
# Avg. Session Length     217
# Time on App             217
# Time on Website         217
# Length of Membership    217
# Yearly Amount Spent     217
# dtype: int64

# %%
# or
len(ecom[(ecom['Time on App']>12) & (ecom['Yearly Amount Spent']>450)])
# Out:
# 217

# %%
# What are the top 5 most popular email provider
# step1
exp = ecom['Email'].iloc[0]

# %%
#step2 
exp
# Out:
# 'mstephenson@fernandez.com'

# %%
#step3
exp.split('@')
# Out:
# ['mstephenson', 'fernandez.com']

# %%
# step 4
exp.split('@')[1]
# Out:
# 'fernandez.com'

# %%
# step 5
ecom['Email'].apply(lambda email: email.split('@')[1])
# Out:
# 0               fernandez.com
# 1                 hotmail.com
# 2                   yahoo.com
# 3                   gmail.com
# 4         davidson-herman.com
# 5                   lucas.biz
# 6                   yahoo.com
# 7                   yahoo.com
# 8         walter-martinez.com
# 9                     lin.biz
# 10               peterson.com
# 11                freeman.biz
# 12                  gmail.com
# 13                  yahoo.com
# 14                  gmail.com
# 15               anderson.com
# 16                  gmail.com
# 17             hale-bauer.biz
# 18                hotmail.com
# 19              love-west.net
# 20                  gmail.com
# 21                  yahoo.com
# 22                hotmail.com
# 23     hernandez-townsend.com
# 24                  yahoo.com
# 25              mcconnell.com
# 26          schaefer-carr.net
# 27                  yahoo.com
# 28              martinez.info
# 29                hotmail.com
#                 ...
# ...

# %%
# step 6
ecom['Email'].apply(lambda email: email.split('@')[1]).value_counts()
# Out:
# hotmail.com               87
# gmail.com                 87
# yahoo.com                 76
# lee.com                    2
# moore.com                  2
# jones.com                  2
# jackson.com                2
# johnson.com                2
# edwards.com                2
# davis.com                  2
# williams.com               2
# barber.com                 2
# foster.net                 1
# sawyer-sellers.com         1
# martinez.info              1
# walsh-obrien.net           1
# scott.com                  1
# cannon.org                 1
# jenkins.info               1
# manning.com                1
# carter.com                 1
# nelson.com                 1
# rose.com                   1
# rosales.com                1
# hale-bauer.biz             1
# lewis.info                 1
# briggs.com                 1
# fuller.com                 1
# carson-hansen.com          1
# christian-riley.com        1
#                           ..
# martin-morgan.com          1
# ...

# %%
# step 7
ecom['Email'].apply(lambda email: email.split('@')[1]).value_counts().head(5)
# Out:
# hotmail.com    87
# gmail.com      87
# yahoo.com      76
# lee.com         2
# moore.com       2
# Name: Email, dtype: int64
